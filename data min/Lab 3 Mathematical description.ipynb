# %%
from statistics import *

# %%
print(mean([1,2,3,4,5]))
# Out:
# 3

# %%
print(mode([1,2,3,4,4]))
# Out:
# 4

# %%
print(mode([1,1,2,3,3,3,4]))
# Out:
# 3

# %%
print(median([1,3,5]))
# Out:
# 3

# %%
print(median_high([1,3,5,7]))
# Out:
# 5

# %%
print(median_low([1,3,5,7]))
# Out:
# 3

# %%
data=[0.0,0.25,0.25,1.25,1.5,1.75,2.75,3.25]
pvariance(data)
# Out:
# 1.25

# %%
stdev([1.5,2.5,2.5,2.75,3.25,4.75])
# Out:
# 1.0810874155219827

# %% [markdown]
# # Histogram

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %%
data=np.random.randn(1000)

# %%
plt.hist(data)
# Out:
# (array([ 11.,  33., 106., 165., 242., 193., 148.,  70.,  28.,   4.]),
#  array([-2.9315322 , -2.32616023, -1.72078826, -1.11541629, -0.51004432,
#          0.09532764,  0.70069961,  1.30607158,  1.91144355,  2.51681552,
#          3.12218748]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data,bins=30,alpha=0.5,histtype='stepfilled',color='steelblue',edgecolor='none')
# Out:
# (array([ 3.,  2.,  6.,  4.,  7., 22., 21., 45., 40., 55., 61., 49., 72.,
#         84., 86., 65., 76., 52., 60., 60., 28., 32., 26., 12., 13.,  8.,
#          7.,  2.,  1.,  1.]),
#  array([-2.9315322 , -2.72974154, -2.52795088, -2.32616023, -2.12436957,
#         -1.92257892, -1.72078826, -1.5189976 , -1.31720695, -1.11541629,
#         -0.91362564, -0.71183498, -0.51004432, -0.30825367, -0.10646301,
#          0.09532764,  0.2971183 ,  0.49890896,  0.70069961,  0.90249027,
#          1.10428092,  1.30607158,  1.50786224,  1.70965289,  1.91144355,
#          2.1132342 ,  2.31502486,  2.51681552,  2.71860617,  2.92039683,
#          3.12218748]),
#  <a list of 1 Patch objects>)

# %% [markdown]
# # scatterplot

# %%
plt.style.use('seaborn-whitegrid')
x=np.linspace(0,10,30)
y=np.sin(x)
plt.plot(x,y,'o',color='red')

# %%
from sklearn.datasets import load_iris
iris=load_iris()
features=iris.data.T

# %%
plt.scatter(features[0],features[1],alpha=0.2,s=100*features[3],c=iris.target,cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %%
plt.scatter(features[0],features[2],alpha=0.2,s=100*features[3],c=iris.target,cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[2])
# Out:
# Text(0, 0.5, 'petal length (cm)')

# %%
plt.scatter(features[1],features[3],alpha=0.2,s=100*features[3],c=iris.target,cmap='viridis')
plt.xlabel(iris.feature_names[1])
plt.ylabel(iris.feature_names[3])
# Out:
# Text(0, 0.5, 'petal width (cm)')

# %%
import seaborn as sns
sns.set(style='ticks',color_codes=True)
iris=sns.load_dataset('iris')
g=sns.pairplot(iris)

# %% [markdown]
# # Lab 5
